# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = np.linspace(5,100,100)
y = np.linspace(10, 1000, 100 )

plt.plot(x,y)
plt.show()

# %%
plt.plot([1,3,5,6],[3,9,6,1])
plt.show()

# %%
plt.plot(x,y)

plt.xlabel("Current")
plt.ylabel("Voltage")
plt.title("Ohm's law")

# plt.xlim([20,80])
# plt.ylim([200,800])

plt.axis((20,80,200, 800))
plt.show()

# %%
x = np.linspace(0,10,20)
y = x**2

plt.plot(x,y,'b+')

plt.xlabel("Current")
plt.ylabel("Voltage")
plt.title("Ohm's law")
# Out:
# Text(0.5, 1.0, "Ohm's law")

# %%
x = np.linspace(0,20,10)
y = np.linspace(2,8, 10)


plt.plot(x,y,"b-", x, y ** 2, 'r^', x, y**3, 'g+')
plt.show()

# %%
# figures and subplots

# %%
x = np.linspace(1,20,10)
y = np.log(x)

plt.figure(1)
plt.subplot(121)
plt.xlabel("x")
plt.ylabel("log y")
plt.title("Graph of log y against x")
plt.plot(x, y)

plt.subplot(122)
plt.xlabel("x")
plt.ylabel("log(y) ** 2")
plt.title("Graph of log(y)^2 against x")
plt.plot(x, y ** 2)


plt.subplots_adjust(wspace=0.3)

# %%
x = np.linspace(1,2,10)

plt.figure(1)
plt.subplot(121)
plt.title("Linear")
plt.plot(x, x)

plt.subplot(122)
plt.title("Cubic")
plt.plot(x, x ** 3)

plt.figure(2)
plt.subplot(221)
plt.title("Log")
plt.plot(x, np.log(x))

plt.subplot(222)
plt.title("Exponential")
plt.plot(x,np.exp(x))

plt.subplots_adjust(wspace=0.3)

# %% [markdown]
# # graphs

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nagamounika5/Datasets/master/Global%20Dataset/Market_Fact.csv")

# %%
df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
plt.boxplot(df["Order_Quantity"])
plt.show()

# %%
plt.boxplot(df["Sales"])
plt.show()

# %%
df["Sales"].describe()
# Out:
# count     8399.000000
# mean      1775.878179
# std       3585.050525
# min          2.240000
# 25%        143.195000
# 50%        449.420000
# 75%       1709.320000
# max      89061.050000
# Name: Sales, dtype: float64

# %%
# in the previous output that the distance between the min and the median is <<<< that between the median and the max

plt.subplot(1,2,1)
plt.boxplot(df["Sales"])

# we will be using the logarithmic scale 
plt.subplot(1,2,2)
plt.boxplot(df["Sales"])
plt.yscale("log")

# %% [markdown]
# # Histogram

# %%
plt.hist(df["Sales"])
plt.show()

# %%
# making the y axis logarithmic 

plt.hist(df["Sales"])
plt.yscale("log")
plt.show()

# %% [markdown]
# # scatter plot
# scatter plot can be used to visualize two or more variables, Profit and Sales.

# %%
# scatter plot 
plt.scatter(df["Sales"], df["Profit"])
plt.show()

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")
df = pd.read_csv("https://raw.githubusercontent.com/nagamounika5/Datasets/master/Global%20Dataset/Market_Fact.csv")

# %%
sns.histplot(df["Shipping_Cost"])
# Out:
# <Axes: xlabel='Shipping_Cost', ylabel='Count'>

# %%
sns.displot(df["Shipping_Cost"])
# Out:
# C:\Users\Max\anaconda3\envs\nb_env\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(df["Shipping_Cost"])
# Out:
# C:\Users\Max\AppData\Local\Temp\ipykernel_21348\1746978865.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Shipping_Cost"])
# <Axes: xlabel='Shipping_Cost', ylabel='Density'>

# %%
sns.distplot(df["Shipping_Cost"][:200], rug=True)
# Out:
# C:\Users\Max\AppData\Local\Temp\ipykernel_21348\3675364497.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Shipping_Cost"][:200], rug=True)
# <Axes: xlabel='Shipping_Cost', ylabel='Density'>

# %%
sns.distplot(df["Shipping_Cost"][:200], hist=False)
# Out:
# C:\Users\Max\AppData\Local\Temp\ipykernel_21348\3681676234.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Shipping_Cost"][:200], hist=False)
# <Axes: xlabel='Shipping_Cost', ylabel='Density'>

# %%
plt.subplot(221)
plt.title("Sales")
sns.distplot(df["Sales"])


plt.subplot(222)
plt.title("Profit")
sns.distplot(df["Profit"])

plt.subplot(223)
sns.distplot(df["Shipping_Cost"])
# plt.title("Shipping_Cost")

plt.subplot(224)
sns.distplot(df["Order_Quantity"])
# plt.title("Order_Quantity")


# sns.distplot(df["Order_Quantity"][:200])
# Out:
# C:\Users\Max\AppData\Local\Temp\ipykernel_21348\2831000332.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Sales"])
# C:\Users\Max\AppData\Local\Temp\ipykernel_21348\2831000332.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Profit"])
# ...

# %%
sns.boxplot(df["Order_Quantity"])
plt.title("Order_Quantity")

plt.show()

# %%
sns.boxplot(df["Sales"])
plt.yscale("log")
plt.title("Sales")

plt.show()

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# %%
sns.jointplot(data=df, x="Sales", y ="Profit")

# %%
sns.jointplot(data=df, x="Sales", y ="Profit")

# %%
df = df[(df["Profit"] < 10000) & (df["Sales"] < 20000)]

# %%
sns.jointplot(data=df, x="Sales", y ="Profit")

# %%
df = df[(df["Profit"] < 100) & (df.Profit > -100) & (df["Sales"] < 200)]

# %%
sns.jointplot(data=df, x="Sales", y ="Profit", color="k", kind="hex")
